# %%
import sys
import numpy as np
import pandas as pd

print("python version:", sys.version)
print("numpy version:", np.__version__)
print("pandas versio:", pd.__version__)
print("setup berhasil, hello world!")
# Out:
# python version: 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]
# numpy version: 2.5.1
# pandas versio: 3.0.3
# setup berhasil, hello world!
